# %%
import pandas as pd

# %%
df_bangalore = pd.read_csv('bangalore_cars_output.csv', low_memory=False)
df_chennai = pd.read_csv('chennai_cars_output.csv', low_memory=False)
df_delhi = pd.read_csv('delhi_cars_output.csv', low_memory=False)
df_hyderabad = pd.read_csv('hyderabad_cars_output.csv', low_memory=False)
df_jaipur = pd.read_csv('jaipur_cars_output.csv', low_memory=False)
df_kolkata = pd.read_csv('kolkata_cars_output.csv', low_memory=False)

# %%
df_bangalore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99633 entries, 0 to 99632
# Data columns (total 75 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   it                        1481 non-null   float64
#  1   ft                        1481 non-null   object
#  2   bt                        1481 non-null   object
#  3   km                        1481 non-null   object
#  4   transmission              1481 non-null   object
#  5   ownerNo                   1481 non-null   float64
#  6   owner                     1481 non-null   object
#  7   oem                       1481 non-null   object
#  8   model                     1481 non-null   object
#  9   modelYear                 1481 non-null   float64
#  10  centralVariantId          1481 non-null   float64
#  11  variantName               1481 non-null   object
#  12  price                     1481 non-null   object
#  13  priceActual               311 non-null    object
#  14  priceSaving               0 non-null      float64
#  15  priceFixedText            0 non-null      float64
#  16  trendingText_imgUrl       1481 non-null   object
#  17  trendingText_heading      1481 non-null   object
#  18  trendingText_desc         1481 non-null   object
#  19  Registration Year         1474 non-null   object
#  20  Insurance Validity        1478 non-null   object
#  21  Fuel Type                 1481 non-null   object
#  22  Seats                     1480 non-null   object
#  23  Kms Driven                1481 non-null   object
#  24  RTO                       1313 non-null   object
#  25  Ownership                 1481 non-null   object
#  26  Engine Displacement       1478 non-null   object
#  27  Transmission              1481 non-null   object
#  28  Year of Manufacture       1474 non-null   float64
#  29  value                     13040 non-null  object
#  30  commonIcon                13040 non-null  object
#  31  value.1                   99633 non-null  object
#  32  heading                   99633 non-null  object
#  33  subHeading                99633 non-null  object
#  34  commonIcon.1              99633 non-null  object
#  35  Mileage                   1439 non-null   object
#  36  Engine                    1478 non-null   object
#  37  Max Power                 1465 non-null   object
#  38  Torque                    1465 non-null   object
#  39  Seats.1                   1480 non-null   float64
#  40  Color                     1479 non-null   object
#  41  Engine Type               1423 non-null   object
#  42  Displacement              1478 non-null   float64
#  43  Max Torque                1465 non-null   object
#  44  No of Cylinder            1475 non-null   float64
#  45  Values per Cylinder       1470 non-null   float64
#  46  Value Configuration       1091 non-null   object
#  47  Fuel Suppy System         1184 non-null   object
#  48  BoreX Stroke              383 non-null    object
#  49  Compression Ratio         317 non-null    object
#  50  Turbo Charger             1288 non-null   object
#  51  Super Charger             1142 non-null   object
#  52  Length                    1460 non-null   object
#  53  Width                     1460 non-null   object
#  54  Height                    1460 non-null   object
#  55  Wheel Base                1446 non-null   object
#  56  Front Tread               882 non-null    object
#  57  Rear Tread                879 non-null    object
#  58  Kerb Weight               1467 non-null   object
#  59  Gross Weight              688 non-null    object
#  60  Gear Box                  1457 non-null   object
#  61  Drive Type                1182 non-null   object
#  62  Seating Capacity          1480 non-null   float64
#  63  Steering Type             1448 non-null   object
#  64  Turning Radius            1198 non-null   object
#  65  Front Brake Type          1460 non-null   object
#  66  Rear Brake Type           1460 non-null   object
#  67  Top Speed                 809 non-null    object
#  68  Acceleration              848 non-null    object
#  69  Tyre Type                 1471 non-null   object
#  70  No Door Numbers           1479 non-null   float64
#  71  Cargo Volumn              1198 non-null   object
#  72  Wheel Size                1029 non-null   object
#  73  Alloy Wheel Size          1029 non-null   object
#  74  Ground Clearance Unladen  87 non-null     object
# dtypes: float64(13), object(62)
# memory usage: 57.0+ MB

# %%
df_bangalore['City'] = 'Bangalore' 
df_chennai['City'] = 'Chennai'
df_delhi['City'] = 'Delhi'
df_hyderabad['City'] = 'Hyderabad'
df_jaipur['City'] = 'Jaipur'
df_kolkata['City'] = 'Kolkata'

# %%
# Drop columns multiple column 
df_bangalore = df_bangalore.drop(['trendingText_imgUrl', 'trendingText_heading', 'trendingText_desc', 
                                  'commonIcon', 'value.1', 'heading', 'subHeading', 'commonIcon.1'], axis=1)

df_chennai = df_chennai.drop(['trendingText_imgUrl', 'trendingText_heading', 'trendingText_desc', 
                                  'commonIcon', 'value.1', 'heading', 'subHeading', 'commonIcon.1'], axis=1)

df_delhi = df_delhi.drop(['trendingText_imgUrl', 'trendingText_heading', 'trendingText_desc', 
                                  'commonIcon', 'value.1', 'heading', 'subHeading', 'commonIcon.1'], axis=1)

df_hyderabad = df_hyderabad.drop(['trendingText_imgUrl', 'trendingText_heading', 'trendingText_desc', 
                                  'commonIcon', 'value.1', 'heading', 'subHeading', 'commonIcon.1'], axis=1)

df_jaipur = df_jaipur.drop(['trendingText_imgUrl', 'trendingText_heading', 'trendingText_desc', 
                                  'commonIcon', 'value.1', 'heading', 'subHeading', 'commonIcon.1'], axis=1)

df_kolkata = df_kolkata.drop(['trendingText_imgUrl', 'trendingText_heading', 'trendingText_desc', 
                                  'commonIcon', 'value.1', 'heading', 'subHeading', 'commonIcon.1'], axis=1)

# %%
df_bangalore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99633 entries, 0 to 99632
# Data columns (total 68 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   it                        1481 non-null   float64
#  1   ft                        1481 non-null   object
#  2   bt                        1481 non-null   object
#  3   km                        1481 non-null   object
#  4   transmission              1481 non-null   object
#  5   ownerNo                   1481 non-null   float64
#  6   owner                     1481 non-null   object
#  7   oem                       1481 non-null   object
#  8   model                     1481 non-null   object
#  9   modelYear                 1481 non-null   float64
#  10  centralVariantId          1481 non-null   float64
#  11  variantName               1481 non-null   object
#  12  price                     1481 non-null   object
#  13  priceActual               311 non-null    object
#  14  priceSaving               0 non-null      float64
#  15  priceFixedText            0 non-null      float64
#  16  Registration Year         1474 non-null   object
#  17  Insurance Validity        1478 non-null   object
#  18  Fuel Type                 1481 non-null   object
#  19  Seats                     1480 non-null   object
#  20  Kms Driven                1481 non-null   object
#  21  RTO                       1313 non-null   object
#  22  Ownership                 1481 non-null   object
#  23  Engine Displacement       1478 non-null   object
#  24  Transmission              1481 non-null   object
#  25  Year of Manufacture       1474 non-null   float64
#  26  value                     13040 non-null  object
#  27  Mileage                   1439 non-null   object
#  28  Engine                    1478 non-null   object
#  29  Max Power                 1465 non-null   object
#  30  Torque                    1465 non-null   object
#  31  Seats.1                   1480 non-null   float64
#  32  Color                     1479 non-null   object
#  33  Engine Type               1423 non-null   object
#  34  Displacement              1478 non-null   float64
#  35  Max Torque                1465 non-null   object
#  36  No of Cylinder            1475 non-null   float64
#  37  Values per Cylinder       1470 non-null   float64
#  38  Value Configuration       1091 non-null   object
#  39  Fuel Suppy System         1184 non-null   object
#  40  BoreX Stroke              383 non-null    object
#  41  Compression Ratio         317 non-null    object
#  42  Turbo Charger             1288 non-null   object
#  43  Super Charger             1142 non-null   object
#  44  Length                    1460 non-null   object
#  45  Width                     1460 non-null   object
#  46  Height                    1460 non-null   object
#  47  Wheel Base                1446 non-null   object
#  48  Front Tread               882 non-null    object
#  49  Rear Tread                879 non-null    object
#  50  Kerb Weight               1467 non-null   object
#  51  Gross Weight              688 non-null    object
#  52  Gear Box                  1457 non-null   object
#  53  Drive Type                1182 non-null   object
#  54  Seating Capacity          1480 non-null   float64
#  55  Steering Type             1448 non-null   object
#  56  Turning Radius            1198 non-null   object
#  57  Front Brake Type          1460 non-null   object
#  58  Rear Brake Type           1460 non-null   object
#  59  Top Speed                 809 non-null    object
#  60  Acceleration              848 non-null    object
#  61  Tyre Type                 1471 non-null   object
#  62  No Door Numbers           1479 non-null   float64
#  63  Cargo Volumn              1198 non-null   object
#  64  Wheel Size                1029 non-null   object
#  65  Alloy Wheel Size          1029 non-null   object
#  66  Ground Clearance Unladen  87 non-null     object
#  67  City                      99633 non-null  object
# dtypes: float64(13), object(55)
# memory usage: 51.7+ MB

# %%
df_all_cities = pd.concat([df_bangalore, df_chennai, df_delhi, df_hyderabad, df_jaipur, df_kolkata], ignore_index=True)

# %%
df_all_cities.head()
# Out:
#     it      ft         bt        km transmission  ownerNo      owner      oem  \
# 0  0.0  Petrol  Hatchback  1,20,000       Manual      3.0  3rd Owner   Maruti
# 1  0.0  Petrol        SUV    32,706       Manual      2.0  2nd Owner     Ford
# 2  0.0  Petrol  Hatchback    11,949       Manual      1.0  1st Owner     Tata
# 3  0.0  Petrol      Sedan    17,794       Manual      1.0  1st Owner  Hyundai
# 4  0.0  Diesel        SUV    60,000       Manual      1.0  1st Owner   Maruti
#
#                 model  modelYear  ...  Rear Brake Type Top Speed  \
# 0      Maruti Celerio     2015.0  ...             Drum  150 Kmph
# 1       Ford Ecosport     2018.0  ...             Drum       NaN
# 2          Tata Tiago     2018.0  ...             Drum  150 kmph
# 3       Hyundai Xcent     2014.0  ...             Drum  172km/hr
# 4  Maruti SX4 S Cross     2015.0  ...       Solid Disc  190 Kmph
#
#     Acceleration         Tyre Type  No Door Numbers  Cargo Volumn Wheel Size  \
# 0  15.05 Seconds  Tubeless, Radial              5.0    235-litres        NaN
# 1            NaN   Tubeless,Radial              4.0    352-litres         16
# 2   14.3 Seconds          Tubeless              5.0    242-litres         14
# 3   14.2 Seconds   Tubeless,Radial              4.0    407-litres         14
# 4     12 Seconds   Tubeless,Radial              5.0    353-litres         16
#
#   Alloy Wheel Size Ground Clearance Unladen       City
# 0              NaN                      NaN  Bangalore
# 1               16                      NaN  Bangalore
# 2               14                      NaN  Bangalore
# 3               14                      NaN  Bangalore
# 4               16                      NaN  Bangalore
#
# [5 rows x 68 columns]

# %%
df = df_all_cities

# %%
# Drop columns NaN columns
df = df.drop(['it' , 'priceFixedText', 'priceSaving', 'priceTrendingText', 'Ground Clearance Unladen', 
              'owner' , 'ownerNo' , 'centralVariantId' , 'variantName' , 'priceActual' , 'priceSaving' , 'priceFixedText' , 'Registration Year' , 
              'Insurance Validity' , 'RTO' , 'Engine Displacement' , 'Torque' , 'Transmission' , 'Max Power' , 'Seats.1' , 'Engine Type' , 'Max Torque' , 
              'No of Cylinder' , 'Values per Cylinder' , 'Value Configuration' , 'Fuel Suppy System' , 'BoreX Stroke' , 'Compression Ratio' , 
              'Turbo Charger' , 'Super Charger' , 'value' , 'Front Tread' , 'Kerb Weight' , 'Gross Weight' , 'Rear Tread' , 'Gear Box' , 'Drive Type' , 'Steering Type' , 'Turning Radius' , 
              'Front Brake Type' , 'Rear Brake Type' , 'Tyre Type' , 'No Door Numbers' , 'Cargo Volumn' , 'Wheel Size' , 'Alloy Wheel Size' , 'Top Speed' , 'Acceleration' , 'Seating Capacity'], axis=1, errors='ignore')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 552269 entries, 0 to 552268
# Data columns (total 22 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ft                   8369 non-null    object
#  1   bt                   8365 non-null    object
#  2   km                   8369 non-null    object
#  3   transmission         8369 non-null    object
#  4   oem                  8369 non-null    object
#  5   model                8369 non-null    object
#  6   modelYear            8369 non-null    float64
#  7   price                8369 non-null    object
#  8   Fuel Type            8369 non-null    object
#  9   Seats                8363 non-null    object
#  10  Kms Driven           8367 non-null    object
#  11  Ownership            8337 non-null    object
#  12  Year of Manufacture  8349 non-null    float64
#  13  Mileage              8082 non-null    object
#  14  Engine               8365 non-null    object
#  15  Color                8366 non-null    object
#  16  Displacement         8365 non-null    float64
#  17  Length               8290 non-null    object
#  18  Width                8286 non-null    object
#  19  Height               8290 non-null    object
#  20  Wheel Base           8206 non-null    object
#  21  City                 552269 non-null  object
# dtypes: float64(3), object(19)
# memory usage: 92.7+ MB

# %%
# Save the cleaned DataFrame to a CSV file
#df.to_csv('All_cities_data.csv', index=False)

# %%
def clean_price(price):
    price = str(price).replace('₹', '').replace(',', '').strip()
    if 'Crore' in price:
        return float(price.replace('Crore', '').strip()) * 10000000
    elif 'Lakh' in price:
        return float(price.replace('Lakh', '').strip()) * 100000
    else:
        return float(price)  # Handle other formats if necessary

df['price'] = df['price'].apply(clean_price)

# %%
df['price'].head(20)
# Out:
# 0      400000.0
# 1      811000.0
# 2      585000.0
# 3      462000.0
# 4      790000.0
# 5     1900000.0
# 6      345000.0
# 7     1200000.0
# 8      960000.0
# 9      585000.0
# 10     690000.0
# 11     682000.0
# 12     825000.0
# 13     595000.0
# 14     690000.0
# 15    1350000.0
# 16    5595000.0
# 17     521000.0
# 18    1005000.0
# 19     775000.0
# Name: price, dtype: float64

# %%
import numpy as np


# Clean and convert 'modelYear' column
df['modelYear'] = df['modelYear'].astype('category')  # converts to category

# Clean and convert 'km' column
df['km'] = df['km'].str.replace(',', '', regex=False).astype(float)  # Temporarily convert to float
df['km'].fillna(df['km'].mean(), inplace=True)  # Fill NaNs with mean
df['km'] = df['km'].astype(int)  # Convert to int

# Clean and convert 'Seats' column
df['Seats'] = df['Seats'].str.replace(' Seats', '', regex=False).astype(float)  # Temporarily convert to float
df['Seats'].fillna(df['Seats'].mean(), inplace=True)  # Fill NaNs with mean
df['Seats'] = df['Seats'].astype(int)  # Convert to int

# Clean and convert 'Kms Driven' column
df['Kms Driven'] = df['Kms Driven'].str.replace(' Kms', '', regex=False).str.replace(',', '', regex=False).astype(float)  # Temporarily convert to float
df['Kms Driven'].fillna(df['Kms Driven'].mean(), inplace=True)  # Fill NaNs with mean
df['Kms Driven'] = df['Kms Driven'].astype(int)  # Convert to int

# Clean and convert 'Mileage' column
df['Mileage'] = df['Mileage'].str.replace(' kmpl', '', regex=False).str.replace(' km/kg', '', regex=False).astype(float)
df['Mileage'].fillna(df['Mileage'].mean(), inplace=True)  # Fill NaNs with mean

# Clean and convert 'Engine' column
df['Engine'] = df['Engine'].str.replace(' CC', '', regex=False).astype(float)  # Temporarily convert to float
df['Engine'].fillna(df['Engine'].mean(), inplace=True)  # Fill NaNs with mean
df['Engine'] = df['Engine'].astype(int)  # Convert to int

# Clean and convert 'Torque' column
#df['Torque'] = df['Torque'].str.replace(' Nm', '', regex=False).str.replace('Nm', '', regex=False).str.replace('nm', '', regex=False).str.replace('NM', '', regex=False).str.replace(' kgm at', '', regex=False).str.replace(' rpm', '', regex=False).str.replace(',', '', regex=False).str.replace(' ', '', regex=False).str.replace('kgm', '', regex=False).str.replace('KGMat', '', regex=False).str.replace('RPM', '', regex=False).str.replace('at', '', regex=False).str.replace('-', '', regex=False).str.replace('rpm', '', regex=False).str.replace('KGM', '', regex=False).str.replace('/', '', regex=False).astype(float)  # Temporarily convert to float
#df['Torque'].fillna(df['Torque'].mean(), inplace=True)  # Fill NaNs with mean

# Convert 'Displacement' column
df['Displacement'] = df['Displacement'].astype(float)  # Temporarily convert to float
df['Displacement'].fillna(df['Displacement'].mean(), inplace=True)  # Fill NaNs with mean
df['Displacement'] = df['Displacement'].astype(int)  # Convert to int

# Clean and convert 'Length', 'Width', 'Height', 'Wheel Base' columns
df['Length'] = df['Length'].str.replace('mm', '', regex=False).str.replace(',', '', regex=False).str.replace(' ', '', regex=False).astype(float)  # Temporarily convert to float
df['Length'].fillna(df['Length'].mean(), inplace=True)  # Fill NaNs with mean
df['Length'] = df['Length'].astype(int)  # Convert to int

df['Width'] = df['Width'].str.replace('mm', '', regex=False).str.replace(',', '', regex=False).str.replace(' ', '', regex=False).astype(float)  # Temporarily convert to float
df['Width'].fillna(df['Width'].mean(), inplace=True)  # Fill NaNs with mean
df['Width'] = df['Width'].astype(int)  # Convert to int

df['Height'] = df['Height'].str.replace('mm', '', regex=False).str.replace(',', '', regex=False).str.replace(' ', '', regex=False).str.replace('-', '', regex=False).astype(float)  # Temporarily convert to float
df['Height'].fillna(df['Height'].mean(), inplace=True)  # Fill NaNs with mean
df['Height'] = df['Height'].astype(int)  # Convert to int

df['Wheel Base'] = df['Wheel Base'].str.replace('mm', '', regex=False).str.replace(',', '', regex=False).str.replace(' ', '', regex=False).str.replace('m', '', regex=False).astype(float)  # Temporarily convert to float
df['Wheel Base'].fillna(df['Wheel Base'].mean(), inplace=True)  # Fill NaNs with mean
df['Wheel Base'] = df['Wheel Base'].astype(int)  # Convert to int

# Clean and convert 'Top Speed' column
#df['Top Speed'] = df['Top Speed'].str.replace('Kmph', '', regex=False).str.replace(',', '', regex=False).str.replace(' kmph', '', regex=False).str.replace('km/hr', '', regex=False).str.replace('kmph', '', regex=False).str.replace(' Km', '', regex=False).str.replace('/Hour', '', regex=False).str.replace('Km', '', regex=False).str.replace('', 'NaN', regex=False).astype(float)  # Temporarily convert to float
#df['Top Speed'].fillna(df['Top Speed'].mean(), inplace=True)  # Fill NaNs with mean
#df['Top Speed'] = df['Top Speed'].astype(int)  # Convert to int

# Clean and convert 'Acceleration' column
#df['Acceleration'] = df['Acceleration'].str.replace('Seconds', '', regex=False).str.replace(' Seconds', '', regex=False).str.replace('seconds', '', regex=False).str.replace(' seconds', '', regex=False).str.replace('Sec', '', regex=False).str.replace(' Sec', '', regex=False).str.replace('s', '', regex=False).str.replace(' s', '', regex=False).str.replace('sec', '', regex=False).str.replace(' sec', '', regex=False).str.replace('ec', '', regex=False).str.replace('m', '', regex=False)str.replace(' cond', '', regex=False).astype(float)
#df['Acceleration'].fillna(df['Acceleration'].mean(), inplace=True)  # Fill NaNs with mean

# Clean and convert 'modelYear' column
df['Year of Manufacture'] = df['Year of Manufacture'].astype('category')  # converts to category

# Convert 'City' to a categorical type if you need to handle it as a categorical feature
df['City'] = df['City'].astype('category')

# Handle missing values in other columns as specified
df['ft'].fillna(df['ft'].mode()[0], inplace=True)
df['bt'].fillna(df['bt'].mode()[0], inplace=True)
df['transmission'].fillna(df['transmission'].mode()[0], inplace=True)
df['oem'].fillna(df['oem'].mode()[0], inplace=True)
df['model'].fillna(df['model'].mode()[0], inplace=True)
df['modelYear'].fillna(df['modelYear'].mode()[0], inplace=True)
df['price'].fillna(df['price'].mean(), inplace=True)
df['Fuel Type'].fillna(df['Fuel Type'].mode()[0], inplace=True)
df['Ownership'].fillna(df['Ownership'].mode()[0], inplace=True)
df['Year of Manufacture'].fillna(df['Year of Manufacture'].mode()[0], inplace=True)
df['Color'].fillna(df['Color'].mode()[0], inplace=True)

# Verify the DataFrame's data types
print(df.info())

# Check for any remaining missing values
print(df.isnull().sum())
# Out:
# C:\Users\Siva\AppData\Local\Temp\ipykernel_11576\247119485.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['km'].fillna(df['km'].mean(), inplace=True)  # Fill NaNs with mean
# C:\Users\Siva\AppData\Local\Temp\ipykernel_11576\247119485.py:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Seats'].fillna(df['Seats'].mean(), inplace=True)  # Fill NaNs with mean
# C:\Users\Siva\AppData\Local\Temp\ipykernel_11576\247119485.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Kms Driven'].fillna(df['Kms Driven'].mean(), inplace=True)  # Fill NaNs with mean
# C:\Users\Siva\AppData\Local\Temp\ipykernel_11576\247119485.py:24: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Mileage'].fillna(df['Mileage'].mean(), inplace=True)  # Fill NaNs with mean
# C:\Users\Siva\AppData\Local\Temp\ipykernel_11576\247119485.py:28: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Engine'].fillna(df['Engine'].mean(), inplace=True)  # Fill NaNs with mean
# C:\Users\Siva\AppData\Local\Temp\ipykernel_11576\247119485.py:37: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Displacement'].fillna(df['Displacement'].mean(), inplace=True)  # Fill NaNs with mean
# C:\Users\Siva\AppData\Local\Temp\ipykernel_11576\247119485.py:42: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Length'].fillna(df['Length'].mean(), inplace=True)  # Fill NaNs with mean
# C:\Users\Siva\AppData\Local\Temp\ipykernel_11576\247119485.py:46: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Width'].fillna(df['Width'].mean(), inplace=True)  # Fill NaNs with mean
# C:\Users\Siva\AppData\Local\Temp\ipykernel_11576\247119485.py:50: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Height'].fillna(df['Height'].mean(), inplace=True)  # Fill NaNs with mean
# C:\Users\Siva\AppData\Local\Temp\ipykernel_11576\247119485.py:54: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Wheel Base'].fillna(df['Wheel Base'].mean(), inplace=True)  # Fill NaNs with mean
# C:\Users\Siva\AppData\Local\Temp\ipykernel_11576\247119485.py:73: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['ft'].fillna(df['ft'].mode()[0], inplace=True)
# C:\Users\Siva\AppData\Local\Temp\ipykernel_11576\247119485.py:74: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['bt'].fillna(df['bt'].mode()[0], inplace=True)
# C:\Users\Siva\AppData\Local\Temp\ipykernel_11576\247119485.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['transmission'].fillna(df['transmission'].mode()[0], inplace=True)
# C:\Users\Siva\AppData\Local\Temp\ipykernel_11576\247119485.py:76: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['oem'].fillna(df['oem'].mode()[0], inplace=True)
# C:\Users\Siva\AppData\Local\Temp\ipykernel_11576\247119485.py:77: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['model'].fillna(df['model'].mode()[0], inplace=True)
# C:\Users\Siva\AppData\Local\Temp\ipykernel_11576\247119485.py:78: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['modelYear'].fillna(df['modelYear'].mode()[0], inplace=True)
# C:\Users\Siva\AppData\Local\Temp\ipykernel_11576\247119485.py:79: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['price'].fillna(df['price'].mean(), inplace=True)
# C:\Users\Siva\AppData\Local\Temp\ipykernel_11576\247119485.py:80: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Fuel Type'].fillna(df['Fuel Type'].mode()[0], inplace=True)
# C:\Users\Siva\AppData\Local\Temp\ipykernel_11576\247119485.py:81: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Ownership'].fillna(df['Ownership'].mode()[0], inplace=True)
# C:\Users\Siva\AppData\Local\Temp\ipykernel_11576\247119485.py:82: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Year of Manufacture'].fillna(df['Year of Manufacture'].mode()[0], inplace=True)
# C:\Users\Siva\AppData\Local\Temp\ipykernel_11576\247119485.py:83: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Color'].fillna(df['Color'].mode()[0], inplace=True)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 552269 entries, 0 to 552268
# Data columns (total 22 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ft                   552269 non-null  object
#  1   bt                   552269 non-null  object
#  2   km                   552269 non-null  int32
#  3   transmission         552269 non-null  object
#  4   oem                  552269 non-null  object
#  5   model                552269 non-null  object
#  6   modelYear            552269 non-null  category
#  7   price                552269 non-null  float64
#  8   Fuel Type            552269 non-null  object
#  9   Seats                552269 non-null  int32
#  10  Kms Driven           552269 non-null  int32
#  11  Ownership            552269 non-null  object
#  12  Year of Manufacture  552269 non-null  category
#  13  Mileage              552269 non-null  float64
#  14  Engine               552269 non-null  int32
#  15  Color                552269 non-null  object
#  16  Displacement         552269 non-null  int32
#  17  Length               552269 non-null  int32
#  18  Width                552269 non-null  int32
#  19  Height               552269 non-null  int32
#  20  Wheel Base           552269 non-null  int32
#  21  City                 552269 non-null  category
# dtypes: category(3), float64(2), int32(9), object(8)
# memory usage: 62.7+ MB
# None
# ft                     0
# bt                     0
# km                     0
# transmission           0
# oem                    0
# model                  0
# modelYear              0
# price                  0
# Fuel Type              0
# Seats                  0
# Kms Driven             0
# Ownership              0
# Year of Manufacture    0
# Mileage                0
# Engine                 0
# Color                  0
# Displacement           0
# Length                 0
# Width                  0
# Height                 0
# Wheel Base             0
# City                   0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 552269 entries, 0 to 552268
# Data columns (total 22 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ft                   552269 non-null  object
#  1   bt                   552269 non-null  object
#  2   km                   552269 non-null  int32
#  3   transmission         552269 non-null  object
#  4   oem                  552269 non-null  object
#  5   model                552269 non-null  object
#  6   modelYear            552269 non-null  category
#  7   price                552269 non-null  float64
#  8   Fuel Type            552269 non-null  object
#  9   Seats                552269 non-null  int32
#  10  Kms Driven           552269 non-null  int32
#  11  Ownership            552269 non-null  object
#  12  Year of Manufacture  552269 non-null  category
#  13  Mileage              552269 non-null  float64
#  14  Engine               552269 non-null  int32
#  15  Color                552269 non-null  object
#  16  Displacement         552269 non-null  int32
#  17  Length               552269 non-null  int32
#  18  Width                552269 non-null  int32
#  19  Height               552269 non-null  int32
#  20  Wheel Base           552269 non-null  int32
#  21  City                 552269 non-null  category
# dtypes: category(3), float64(2), int32(9), object(8)
# memory usage: 62.7+ MB

# %%
print(df.shape)
# Out:
# (552269, 22)

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df.head()
# Out:
#        ft         bt      km transmission      oem               model  \
# 0  Petrol  Hatchback  120000       Manual   Maruti      Maruti Celerio
# 1  Petrol        SUV   32706       Manual     Ford       Ford Ecosport
# 2  Petrol  Hatchback   11949       Manual     Tata          Tata Tiago
# 3  Petrol      Sedan   17794       Manual  Hyundai       Hyundai Xcent
# 4  Diesel        SUV   60000       Manual   Maruti  Maruti SX4 S Cross
#
#   modelYear     price Fuel Type  Seats  ...  Year of Manufacture Mileage  \
# 0    2015.0  400000.0    Petrol      5  ...               2015.0   23.10
# 1    2018.0  811000.0    Petrol      5  ...               2018.0   17.00
# 2    2018.0  585000.0    Petrol      5  ...               2018.0   23.84
# 3    2014.0  462000.0    Petrol      5  ...               2014.0   19.10
# 4    2015.0  790000.0    Diesel      5  ...               2015.0   23.65
#
#   Engine   Color  Displacement Length  Width  Height  Wheel Base       City
# 0    998   White           998   3715   1635    1565        2425  Bangalore
# 1   1497   White          1497   3998   1765    1647        2519  Bangalore
# 2   1199     Red          1199   3746   1647    1535        2400  Bangalore
# 3   1197  Others          1197   3995   1660    1520        2425  Bangalore
# 4   1248    Gray          1248   4300   1785    1595        2600  Bangalore
#
# [5 rows x 22 columns]

# %%
print(df.describe())
# Out:
#                  km         price          Seats    Kms Driven        Mileage  \
# count  5.522690e+05  5.522690e+05  552269.000000  5.522690e+05  552269.000000
# mean   5.897400e+04  9.569037e+05       5.003078  5.898801e+04      19.255853
# std    9.116444e+03  1.743257e+05       0.085368  9.115753e+03       0.487564
# min    0.000000e+00  2.016100e+04       2.000000  1.010000e+02       7.080000
# 25%    5.897400e+04  9.569037e+05       5.000000  5.898800e+04      19.255853
# 50%    5.897400e+04  9.569037e+05       5.000000  5.898800e+04      19.255853
# 75%    5.897400e+04  9.569037e+05       5.000000  5.898800e+04      19.255853
# max    5.500000e+06  4.150000e+07      10.000000  5.500000e+06     140.000000
#
#               Engine   Displacement         Length          Width  \
# count  552269.000000  552269.000000  552269.000000  552269.000000
# mean     1424.011147    1424.011147    4105.007741    1731.005070
# std        58.779163      58.779163      48.939559      15.715546
# min         0.000000       0.000000    2974.000000    1410.000000
# 25%      1424.000000    1424.000000    4105.000000    1731.000000
# 50%      1424.000000    1424.000000    4105.000000    1731.000000
# 75%      1424.000000    1424.000000    4105.000000    1731.000000
# max      5000.000000    5000.000000    5462.000000    2220.000000
#
#              Height     Wheel Base
# count  5.522690e+05  552269.000000
# mean   1.964001e+04    2548.008568
# std    6.370489e+04      18.853205
# min    1.288000e+03    1840.000000
# 25%    1.964000e+04    2548.000000
# 50%    1.964000e+04    2548.000000
# 75%    1.964000e+04    2548.000000
# max    1.498150e+07    3365.000000

# %%
df.columns
# Out:
# Index(['ft', 'bt', 'km', 'transmission', 'oem', 'model', 'modelYear', 'price',
#        'Fuel Type', 'Seats', 'Kms Driven', 'Ownership', 'Year of Manufacture',
#        'Mileage', 'Engine', 'Color', 'Displacement', 'Length', 'Width',
#        'Height', 'Wheel Base', 'City'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 552269 entries, 0 to 552268
# Data columns (total 22 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ft                   552269 non-null  object
#  1   bt                   552269 non-null  object
#  2   km                   552269 non-null  int32
#  3   transmission         552269 non-null  object
#  4   oem                  552269 non-null  object
#  5   model                552269 non-null  object
#  6   modelYear            552269 non-null  category
#  7   price                552269 non-null  float64
#  8   Fuel Type            552269 non-null  object
#  9   Seats                552269 non-null  int32
#  10  Kms Driven           552269 non-null  int32
#  11  Ownership            552269 non-null  object
#  12  Year of Manufacture  552269 non-null  category
#  13  Mileage              552269 non-null  float64
#  14  Engine               552269 non-null  int32
#  15  Color                552269 non-null  object
#  16  Displacement         552269 non-null  int32
#  17  Length               552269 non-null  int32
#  18  Width                552269 non-null  int32
#  19  Height               552269 non-null  int32
#  20  Wheel Base           552269 non-null  int32
#  21  City                 552269 non-null  category
# dtypes: category(3), float64(2), int32(9), object(8)
# memory usage: 62.7+ MB

# %%
# Numeric columns selection
numeric_columns = ['km', 'price', 'Seats', 'Kms Driven', 'Mileage', 'Engine', 'Displacement', 'Length', 'Width', 'Height', 'Wheel Base']
Numeric_df = df[numeric_columns].copy()

# Categorical columns selection
categorical_columns = ['ft', 'bt', 'transmission', 'oem', 'model', 'modelYear', 'Fuel Type', 'Ownership', 'Year of Manufacture', 'Color', 'City']
Categorical_df = df[categorical_columns].copy()

# %%
# Scatter plot and Correlation Heatmap 

import matplotlib.pyplot as plt
import seaborn as sns

# Generate scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(Numeric_df['Mileage'], Numeric_df['price'])
plt.xlabel('Mileage')
plt.ylabel('price')
plt.title('price vs Mileage')
plt.show()

# Generate correlation heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(Numeric_df.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %%
# Histograms

numeric_columns = df.select_dtypes(include=['number']).columns

num_columns = len(numeric_columns)
num_rows = (num_columns + 3) // 4  # Adjust the number of rows as needed
num_cols = 4

plt.figure(figsize=(12, 4 * num_rows))
for i, col in enumerate(numeric_columns):
    plt.subplot(num_rows, num_cols, i + 1)
    plt.hist(df[col], bins=30, edgecolor='k')
    plt.title(f'Histogram of {col}')
    plt.tight_layout()

plt.show()

# %%
# Box Plots

# Filter only numeric columns for plotting
numeric_columns = df.select_dtypes(include=['number']).columns

# Calculate the number of rows and columns needed
num_cols = 4  # Number of columns in the subplot grid
num_rows = (len(numeric_columns) + num_cols - 1) // num_cols  # Compute number of rows needed

plt.figure(figsize=(12, 4 * num_rows))

for i, col in enumerate(numeric_columns):
    plt.subplot(num_rows, num_cols, i + 1)
    sns.boxplot(df[col].dropna())  # Drop NA values for plotting
    plt.title(f'Box Plot of {col}')

plt.tight_layout()
plt.show()

# %%
# Scatter Pair Plots

plt.figure(figsize=(12, 8))
sns.pairplot(df)
plt.show()

# %%
non_numeric_cols = X.select_dtypes(exclude=['number']).columns
print("Non-numeric columns:", non_numeric_cols)
# Out:
# Non-numeric columns: Index(['ft', 'bt', 'transmission', 'oem', 'model', 'modelYear', 'Fuel Type',
#        'Ownership', 'Year of Manufacture', 'Color', 'City'],
#       dtype='object')

# %%
# Save the cleaned DataFrame to a CSV file
df.to_csv('All_cities_cleaned_data.csv', index=False)
